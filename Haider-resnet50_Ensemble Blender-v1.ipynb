# %% [markdown]
# ## Ensemble Blender

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
from pathlib import Path
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

from fastai import *
from fastai.vision import *

from utils import open_4_channel
from resnet_v2 import Resnet4Channel

# %%
gpu_device = 0

defaults.device = torch.device(f'cuda:{gpu_device}')
torch.cuda.set_device(gpu_device)

# %%
path = Path('/home/haider/data/human_protein_atlas/')

# %%
# df = pd.read_csv(path/'train.csv')
# df.head()

# %%
np.random.seed(42)
src = (ImageItemList.from_csv(path, 'train.csv', folder='train', suffix='.png')
       .random_split_by_pct(0.2)
       .label_from_df(sep=' ',  classes=[str(i) for i in range(28)]))

# %%
src.train.x.create_func = open_4_channel
src.train.x.open = open_4_channel

# %%
src.valid.x.create_func = open_4_channel
src.valid.x.open = open_4_channel

# %%
test_ids = list(sorted({fname.split('_')[0] for fname in os.listdir(path/'test')}))

# %%
test_fnames = [path/'test'/test_id for test_id in test_ids]

# %%
test_fnames[:5]
# Out:
# [PosixPath('/home/haider/data/human_protein_atlas/test/00008af0-bad0-11e8-b2b8-ac1f6b6435d0'),
#  PosixPath('/home/haider/data/human_protein_atlas/test/0000a892-bacf-11e8-b2b8-ac1f6b6435d0'),
#  PosixPath('/home/haider/data/human_protein_atlas/test/0006faa6-bac7-11e8-b2b7-ac1f6b6435d0'),
#  PosixPath('/home/haider/data/human_protein_atlas/test/0008baca-bad7-11e8-b2b9-ac1f6b6435d0'),
#  PosixPath('/home/haider/data/human_protein_atlas/test/000cce7e-bad4-11e8-b2b8-ac1f6b6435d0')]

# %%
src.add_test(test_fnames, label='0');

# %%
src.test.x.create_func = open_4_channel
src.test.x.open = open_4_channel

# %%
protein_stats = ([0.08069, 0.05258, 0.05487, 0.08282], [0.13704, 0.10145, 0.15313, 0.13814])

# %%
trn_tfms,_ = get_transforms(do_flip=True, flip_vert=True, max_rotate=30., max_zoom=1,
                      max_lighting=0.05, max_warp=0.)

# %%
NUM_WORKERS = 8
BS = 64//4

# %%
data = (src.transform((trn_tfms, _), size=512)
        .databunch(bs=BS, num_workers=NUM_WORKERS).normalize(protein_stats))

#        .normalize(imagenet_stats)

# %%
# data.show_batch(rows=3, figsize=(12,9))

# %%
def resnet50(pretrained):
    return Resnet4Channel(encoder_depth=50)

# %%
# copied from https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py
def _resnet_split(m): 
    # import pdb; pdb.set_trace()  ; m[0] returns the body ; m[0][6] returns the 7th block of the body ; m[1] returns the head; 
    # so it seems this function specifies the points that divides the 3 groups for the differential learning rates
    return (m[0][6],m[1])

# %%
f1_score = partial(fbeta, thresh=0.2, beta=1)

# %%
learn = create_cnn(
    data,
    resnet50,
    cut=-2,
    split_on=_resnet_split,
    loss_func=F.binary_cross_entropy_with_logits,
    path=path,    
    metrics=[f1_score], 
)

# %%
models = ['stage-2-rn50_sz512', 
          'stage-2-rn50_sz512-os', 
          'stage-2-rn50_sz512_both', 
          'stage-2-rn50_sz512-os-from-extrads']

# %%
preds = torch.zeros([4, 6214, 28])
y = torch.zeros([5, 6214, 28])
for i,m in enumerate(models):
    learn.load(m)
    preds[i],y[i] = learn.get_preds(DatasetType.Valid)

# %%
preds.size()
# Out:
# torch.Size([4, 6214, 28])

# %%
preds = preds.mean(0)
preds.size()
# Out:
# torch.Size([6214, 28])

# %%
y.size()
# Out:
# torch.Size([5, 6214, 28])

# %%
y = y.mean(0)
y.size()
# Out:
# torch.Size([6214, 28])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import scipy.optimize as opt

# preds_y = model.predict(valid_x) # in his code mine is : preds_y -> preds; valid_y -> y

thresholds = np.linspace(0, 1, 1500)
score = 0.0
best_threshold=0.0
best_val = 0.0
for threshold in thresholds:
    score = f1_score(y > 0.5, preds > threshold, average='macro')
    if score > best_val:
        best_threshold = threshold
        best_val = score
    print("Threshold %0.4f, F1: %0.4f" % (threshold,score))

print("BEST: %0.5f, F1: %0.5f" % (best_threshold,best_val))
# Out:
# Threshold 0.0000, F1: 0.0992
# Threshold 0.0007, F1: 0.1362
# Threshold 0.0013, F1: 0.1640
# Threshold 0.0020, F1: 0.1872
# Threshold 0.0027, F1: 0.2074
# Threshold 0.0033, F1: 0.2253
# Threshold 0.0040, F1: 0.2412
# Threshold 0.0047, F1: 0.2555
# Threshold 0.0053, F1: 0.2704
# Threshold 0.0060, F1: 0.2834
# Threshold 0.0067, F1: 0.2963
# Threshold 0.0073, F1: 0.3080
# Threshold 0.0080, F1: 0.3179
# Threshold 0.0087, F1: 0.3286
# Threshold 0.0093, F1: 0.3402
# Threshold 0.0100, F1: 0.3499
# Threshold 0.0107, F1: 0.3624
# Threshold 0.0113, F1: 0.3721
# Threshold 0.0120, F1: 0.3823
# Threshold 0.0127, F1: 0.3912
# Threshold 0.0133, F1: 0.4009
# Threshold 0.0140, F1: 0.4070
# Threshold 0.0147, F1: 0.4156
# Threshold 0.0153, F1: 0.4230
# Threshold 0.0160, F1: 0.4279
# Threshold 0.0167, F1: 0.4352
# Threshold 0.0173, F1: 0.4408
# Threshold 0.0180, F1: 0.4452
# Threshold 0.0187, F1: 0.4545
# Threshold 0.0193, F1: 0.4613
# Threshold 0.0200, F1: 0.4663
# Threshold 0.0207, F1: 0.4709
# Threshold 0.0213, F1: 0.4762
# Threshold 0.0220, F1: 0.4816
# Threshold 0.0227, F1: 0.4866
# Threshold 0.0233, F1: 0.4977
# Threshold 0.0240, F1: 0.5043
# Threshold 0.0247, F1: 0.5081
# Threshold 0.0254, F1: 0.5193
# Threshold 0.0260, F1: 0.5238
# Threshold 0.0267, F1: 0.5302
# Threshold 0.0274, F1: 0.5355
# Threshold 0.0280, F1: 0.5397
# Threshold 0.0287, F1: 0.5431
# Threshold 0.0294, F1: 0.5469
# Threshold 0.0300, F1: 0.5498
# Threshold 0.0307, F1: 0.5526
# Threshold 0.0314, F1: 0.5553
# Threshold 0.0320, F1: 0.5583
# Threshold 0.0327, F1: 0.5608
# Threshold 0.0334, F1: 0.5632
# Threshold 0.0340, F1: 0.5671
# Threshold 0.0347, F1: 0.5694
# Threshold 0.0354, F1: 0.5725
# Threshold 0.0360, F1: 0.5756
# Threshold 0.0367, F1: 0.5791
# Threshold 0.0374, F1: 0.5822
# Threshold 0.0380, F1: 0.5844
# Threshold 0.0387, F1: 0.5872
# Threshold 0.0394, F1: 0.5915
# Threshold 0.0400, F1: 0.5934
# Threshold 0.0407, F1: 0.5958
# Threshold 0.0414, F1: 0.5981
# Threshold 0.0420, F1: 0.5998
# Threshold 0.0427, F1: 0.6024
# Threshold 0.0434, F1: 0.6050
# Threshold 0.0440, F1: 0.6055
# Threshold 0.0447, F1: 0.6080
# Threshold 0.0454, F1: 0.6098
# Threshold 0.0460, F1: 0.6116
# Threshold 0.0467, F1: 0.6137
# Threshold 0.0474, F1: 0.6153
# Threshold 0.0480, F1: 0.6174
# Threshold 0.0487, F1: 0.6194
# Threshold 0.0494, F1: 0.6220
# Threshold 0.0500, F1: 0.6239
# Threshold 0.0507, F1: 0.6251
# Threshold 0.0514, F1: 0.6293
# Threshold 0.0520, F1: 0.6315
# Threshold 0.0527, F1: 0.6346
# Threshold 0.0534, F1: 0.6398
# Threshold 0.0540, F1: 0.6409
# Threshold 0.0547, F1: 0.6426
# Threshold 0.0554, F1: 0.6451
# Threshold 0.0560, F1: 0.6471
# Threshold 0.0567, F1: 0.6476
# Threshold 0.0574, F1: 0.6491
# Threshold 0.0580, F1: 0.6508
# Threshold 0.0587, F1: 0.6549
# Threshold 0.0594, F1: 0.6573
# Threshold 0.0600, F1: 0.6588
# Threshold 0.0607, F1: 0.6614
# Threshold 0.0614, F1: 0.6630
# Threshold 0.0620, F1: 0.6638
# Threshold 0.0627, F1: 0.6650
# Threshold 0.0634, F1: 0.6675
# Threshold 0.0640, F1: 0.6686
# Threshold 0.0647, F1: 0.6691
# Threshold 0.0654, F1: 0.6702
# Threshold 0.0660, F1: 0.6724
# Threshold 0.0667, F1: 0.6750
# Threshold 0.0674, F1: 0.6758
# Threshold 0.0680, F1: 0.6771
# Threshold 0.0687, F1: 0.6801
# Threshold 0.0694, F1: 0.6804
# Threshold 0.0700, F1: 0.6819
# Threshold 0.0707, F1: 0.6840
# Threshold 0.0714, F1: 0.6853
# Threshold 0.0720, F1: 0.6869
# Threshold 0.0727, F1: 0.6877
# Threshold 0.0734, F1: 0.6889
# Threshold 0.0740, F1: 0.6905
# Threshold 0.0747, F1: 0.6912
# Threshold 0.0754, F1: 0.6926
# Threshold 0.0761, F1: 0.6940
# Threshold 0.0767, F1: 0.6956
# Threshold 0.0774, F1: 0.6964
# Threshold 0.0781, F1: 0.6973
# Threshold 0.0787, F1: 0.6986
# Threshold 0.0794, F1: 0.6989
# Threshold 0.0801, F1: 0.7013
# Threshold 0.0807, F1: 0.7028
# Threshold 0.0814, F1: 0.7041
# Threshold 0.0821, F1: 0.7046
# Threshold 0.0827, F1: 0.7058
# Threshold 0.0834, F1: 0.7080
# Threshold 0.0841, F1: 0.7087
# Threshold 0.0847, F1: 0.7095
# Threshold 0.0854, F1: 0.7104
# Threshold 0.0861, F1: 0.7114
# Threshold 0.0867, F1: 0.7127
# Threshold 0.0874, F1: 0.7136
# Threshold 0.0881, F1: 0.7145
# Threshold 0.0887, F1: 0.7155
# Threshold 0.0894, F1: 0.7159
# Threshold 0.0901, F1: 0.7167
# Threshold 0.0907, F1: 0.7176
# Threshold 0.0914, F1: 0.7181
# Threshold 0.0921, F1: 0.7190
# Threshold 0.0927, F1: 0.7201
# Threshold 0.0934, F1: 0.7205
# Threshold 0.0941, F1: 0.7208
# Threshold 0.0947, F1: 0.7216
# Threshold 0.0954, F1: 0.7221
# Threshold 0.0961, F1: 0.7228
# Threshold 0.0967, F1: 0.7236
# Threshold 0.0974, F1: 0.7244
# Threshold 0.0981, F1: 0.7255
# Threshold 0.0987, F1: 0.7262
# Threshold 0.0994, F1: 0.7267
# Threshold 0.1001, F1: 0.7273
# Threshold 0.1007, F1: 0.7283
# Threshold 0.1014, F1: 0.7286
# Threshold 0.1021, F1: 0.7288
# Threshold 0.1027, F1: 0.7293
# Threshold 0.1034, F1: 0.7278
# Threshold 0.1041, F1: 0.7284
# Threshold 0.1047, F1: 0.7293
# Threshold 0.1054, F1: 0.7299
# Threshold 0.1061, F1: 0.7304
# Threshold 0.1067, F1: 0.7313
# Threshold 0.1074, F1: 0.7315
# Threshold 0.1081, F1: 0.7322
# Threshold 0.1087, F1: 0.7331
# Threshold 0.1094, F1: 0.7339
# Threshold 0.1101, F1: 0.7344
# Threshold 0.1107, F1: 0.7346
# Threshold 0.1114, F1: 0.7348
# Threshold 0.1121, F1: 0.7365
# Threshold 0.1127, F1: 0.7373
# Threshold 0.1134, F1: 0.7379
# Threshold 0.1141, F1: 0.7391
# Threshold 0.1147, F1: 0.7398
# Threshold 0.1154, F1: 0.7407
# Threshold 0.1161, F1: 0.7412
# Threshold 0.1167, F1: 0.7418
# Threshold 0.1174, F1: 0.7423
# Threshold 0.1181, F1: 0.7445
# Threshold 0.1187, F1: 0.7453
# Threshold 0.1194, F1: 0.7461
# Threshold 0.1201, F1: 0.7464
# Threshold 0.1207, F1: 0.7473
# Threshold 0.1214, F1: 0.7475
# Threshold 0.1221, F1: 0.7480
# Threshold 0.1227, F1: 0.7485
# Threshold 0.1234, F1: 0.7495
# Threshold 0.1241, F1: 0.7495
# Threshold 0.1247, F1: 0.7499
# Threshold 0.1254, F1: 0.7520
# Threshold 0.1261, F1: 0.7531
# Threshold 0.1268, F1: 0.7537
# Threshold 0.1274, F1: 0.7540
# Threshold 0.1281, F1: 0.7545
# Threshold 0.1288, F1: 0.7549
# Threshold 0.1294, F1: 0.7554
# Threshold 0.1301, F1: 0.7558
# Threshold 0.1308, F1: 0.7564
# Threshold 0.1314, F1: 0.7568
# Threshold 0.1321, F1: 0.7577
# Threshold 0.1328, F1: 0.7583
# Threshold 0.1334, F1: 0.7592
# Threshold 0.1341, F1: 0.7597
# Threshold 0.1348, F1: 0.7599
# Threshold 0.1354, F1: 0.7601
# Threshold 0.1361, F1: 0.7605
# Threshold 0.1368, F1: 0.7608
# Threshold 0.1374, F1: 0.7613
# Threshold 0.1381, F1: 0.7617
# Threshold 0.1388, F1: 0.7619
# Threshold 0.1394, F1: 0.7650
# Threshold 0.1401, F1: 0.7657
# Threshold 0.1408, F1: 0.7664
# Threshold 0.1414, F1: 0.7664
# Threshold 0.1421, F1: 0.7673
# Threshold 0.1428, F1: 0.7675
# Threshold 0.1434, F1: 0.7681
# Threshold 0.1441, F1: 0.7688
# Threshold 0.1448, F1: 0.7691
# Threshold 0.1454, F1: 0.7692
# Threshold 0.1461, F1: 0.7697
# Threshold 0.1468, F1: 0.7698
# Threshold 0.1474, F1: 0.7700
# Threshold 0.1481, F1: 0.7708
# Threshold 0.1488, F1: 0.7710
# Threshold 0.1494, F1: 0.7712
# Threshold 0.1501, F1: 0.7708
# Threshold 0.1508, F1: 0.7709
# Threshold 0.1514, F1: 0.7713
# Threshold 0.1521, F1: 0.7718
# Threshold 0.1528, F1: 0.7721
# Threshold 0.1534, F1: 0.7717
# Threshold 0.1541, F1: 0.7722
# Threshold 0.1548, F1: 0.7726
# Threshold 0.1554, F1: 0.7731
# Threshold 0.1561, F1: 0.7733
# Threshold 0.1568, F1: 0.7739
# Threshold 0.1574, F1: 0.7743
# Threshold 0.1581, F1: 0.7746
# Threshold 0.1588, F1: 0.7747
# Threshold 0.1594, F1: 0.7749
# Threshold 0.1601, F1: 0.7751
# Threshold 0.1608, F1: 0.7751
# Threshold 0.1614, F1: 0.7750
# Threshold 0.1621, F1: 0.7756
# Threshold 0.1628, F1: 0.7760
# Threshold 0.1634, F1: 0.7767
# Threshold 0.1641, F1: 0.7772
# Threshold 0.1648, F1: 0.7774
# Threshold 0.1654, F1: 0.7777
# Threshold 0.1661, F1: 0.7778
# Threshold 0.1668, F1: 0.7783
# Threshold 0.1674, F1: 0.7783
# Threshold 0.1681, F1: 0.7788
# Threshold 0.1688, F1: 0.7783
# Threshold 0.1694, F1: 0.7785
# Threshold 0.1701, F1: 0.7789
# Threshold 0.1708, F1: 0.7794
# Threshold 0.1714, F1: 0.7797
# Threshold 0.1721, F1: 0.7802
# Threshold 0.1728, F1: 0.7805
# Threshold 0.1734, F1: 0.7807
# Threshold 0.1741, F1: 0.7814
# Threshold 0.1748, F1: 0.7814
# Threshold 0.1755, F1: 0.7820
# Threshold 0.1761, F1: 0.7828
# Threshold 0.1768, F1: 0.7832
# Threshold 0.1775, F1: 0.7836
# Threshold 0.1781, F1: 0.7835
# Threshold 0.1788, F1: 0.7839
# Threshold 0.1795, F1: 0.7842
# Threshold 0.1801, F1: 0.7845
# Threshold 0.1808, F1: 0.7854
# Threshold 0.1815, F1: 0.7855
# Threshold 0.1821, F1: 0.7856
# Threshold 0.1828, F1: 0.7859
# Threshold 0.1835, F1: 0.7861
# Threshold 0.1841, F1: 0.7863
# Threshold 0.1848, F1: 0.7861
# Threshold 0.1855, F1: 0.7862
# Threshold 0.1861, F1: 0.7862
# Threshold 0.1868, F1: 0.7861
# Threshold 0.1875, F1: 0.7867
# Threshold 0.1881, F1: 0.7866
# Threshold 0.1888, F1: 0.7870
# Threshold 0.1895, F1: 0.7874
# Threshold 0.1901, F1: 0.7880
# Threshold 0.1908, F1: 0.7885
# Threshold 0.1915, F1: 0.7883
# Threshold 0.1921, F1: 0.7884
# Threshold 0.1928, F1: 0.7887
# Threshold 0.1935, F1: 0.7890
# Threshold 0.1941, F1: 0.7887
# Threshold 0.1948, F1: 0.7892
# Threshold 0.1955, F1: 0.7893
# Threshold 0.1961, F1: 0.7895
# Threshold 0.1968, F1: 0.7779
# Threshold 0.1975, F1: 0.7783
# Threshold 0.1981, F1: 0.7787
# Threshold 0.1988, F1: 0.7789
# Threshold 0.1995, F1: 0.7791
# Threshold 0.2001, F1: 0.7796
# Threshold 0.2008, F1: 0.7802
# Threshold 0.2015, F1: 0.7806
# Threshold 0.2021, F1: 0.7807
# Threshold 0.2028, F1: 0.7811
# Threshold 0.2035, F1: 0.7817
# Threshold 0.2041, F1: 0.7813
# Threshold 0.2048, F1: 0.7817
# Threshold 0.2055, F1: 0.7818
# Threshold 0.2061, F1: 0.7820
# Threshold 0.2068, F1: 0.7823
# Threshold 0.2075, F1: 0.7826
# Threshold 0.2081, F1: 0.7826
# Threshold 0.2088, F1: 0.7827
# Threshold 0.2095, F1: 0.7829
# Threshold 0.2101, F1: 0.7831
# Threshold 0.2108, F1: 0.7822
# Threshold 0.2115, F1: 0.7826
# Threshold 0.2121, F1: 0.7828
# Threshold 0.2128, F1: 0.7825
# Threshold 0.2135, F1: 0.7830
# Threshold 0.2141, F1: 0.7830
# Threshold 0.2148, F1: 0.7833
# Threshold 0.2155, F1: 0.7834
# Threshold 0.2161, F1: 0.7837
# Threshold 0.2168, F1: 0.7836
# Threshold 0.2175, F1: 0.7837
# Threshold 0.2181, F1: 0.7839
# Threshold 0.2188, F1: 0.7841
# Threshold 0.2195, F1: 0.7842
# Threshold 0.2201, F1: 0.7846
# Threshold 0.2208, F1: 0.7847
# Threshold 0.2215, F1: 0.7872
# Threshold 0.2221, F1: 0.7873
# Threshold 0.2228, F1: 0.7872
# Threshold 0.2235, F1: 0.7874
# Threshold 0.2241, F1: 0.7876
# Threshold 0.2248, F1: 0.7876
# Threshold 0.2255, F1: 0.7878
# Threshold 0.2262, F1: 0.7878
# Threshold 0.2268, F1: 0.7882
# Threshold 0.2275, F1: 0.7882
# Threshold 0.2282, F1: 0.7882
# Threshold 0.2288, F1: 0.7883
# Threshold 0.2295, F1: 0.7884
# Threshold 0.2302, F1: 0.7885
# Threshold 0.2308, F1: 0.7888
# Threshold 0.2315, F1: 0.7892
# Threshold 0.2322, F1: 0.7897
# Threshold 0.2328, F1: 0.7900
# Threshold 0.2335, F1: 0.7900
# Threshold 0.2342, F1: 0.7901
# Threshold 0.2348, F1: 0.7906
# Threshold 0.2355, F1: 0.7905
# Threshold 0.2362, F1: 0.7908
# Threshold 0.2368, F1: 0.7911
# Threshold 0.2375, F1: 0.7912
# Threshold 0.2382, F1: 0.7914
# Threshold 0.2388, F1: 0.7911
# Threshold 0.2395, F1: 0.7916
# Threshold 0.2402, F1: 0.7917
# Threshold 0.2408, F1: 0.7920
# Threshold 0.2415, F1: 0.7920
# Threshold 0.2422, F1: 0.7921
# Threshold 0.2428, F1: 0.7923
# Threshold 0.2435, F1: 0.7892
# Threshold 0.2442, F1: 0.7893
# Threshold 0.2448, F1: 0.7895
# Threshold 0.2455, F1: 0.7898
# Threshold 0.2462, F1: 0.7902
# Threshold 0.2468, F1: 0.7901
# Threshold 0.2475, F1: 0.7898
# Threshold 0.2482, F1: 0.7899
# Threshold 0.2488, F1: 0.7901
# Threshold 0.2495, F1: 0.7901
# Threshold 0.2502, F1: 0.7901
# Threshold 0.2508, F1: 0.7901
# Threshold 0.2515, F1: 0.7904
# Threshold 0.2522, F1: 0.7904
# Threshold 0.2528, F1: 0.7889
# Threshold 0.2535, F1: 0.7890
# Threshold 0.2542, F1: 0.7891
# Threshold 0.2548, F1: 0.7889
# Threshold 0.2555, F1: 0.7890
# Threshold 0.2562, F1: 0.7893
# Threshold 0.2568, F1: 0.7891
# Threshold 0.2575, F1: 0.7892
# Threshold 0.2582, F1: 0.7893
# Threshold 0.2588, F1: 0.7893
# Threshold 0.2595, F1: 0.7894
# Threshold 0.2602, F1: 0.7898
# Threshold 0.2608, F1: 0.7901
# Threshold 0.2615, F1: 0.7905
# Threshold 0.2622, F1: 0.7889
# Threshold 0.2628, F1: 0.7887
# Threshold 0.2635, F1: 0.7887
# Threshold 0.2642, F1: 0.7893
# Threshold 0.2648, F1: 0.7874
# Threshold 0.2655, F1: 0.7868
# Threshold 0.2662, F1: 0.7865
# Threshold 0.2668, F1: 0.7863
# Threshold 0.2675, F1: 0.7863
# Threshold 0.2682, F1: 0.7867
# Threshold 0.2688, F1: 0.7868
# Threshold 0.2695, F1: 0.7865
# Threshold 0.2702, F1: 0.7869
# Threshold 0.2708, F1: 0.7868
# Threshold 0.2715, F1: 0.7870
# Threshold 0.2722, F1: 0.7871
# Threshold 0.2728, F1: 0.7873
# Threshold 0.2735, F1: 0.7875
# Threshold 0.2742, F1: 0.7868
# Threshold 0.2748, F1: 0.7874
# Threshold 0.2755, F1: 0.7873
# Threshold 0.2762, F1: 0.7873
# Threshold 0.2769, F1: 0.7873
# Threshold 0.2775, F1: 0.7869
# Threshold 0.2782, F1: 0.7868
# Threshold 0.2789, F1: 0.7869
# Threshold 0.2795, F1: 0.7869
# Threshold 0.2802, F1: 0.7869
# Threshold 0.2809, F1: 0.7869
# Threshold 0.2815, F1: 0.7870
# Threshold 0.2822, F1: 0.7871
# Threshold 0.2829, F1: 0.7872
# Threshold 0.2835, F1: 0.7868
# Threshold 0.2842, F1: 0.7869
# Threshold 0.2849, F1: 0.7869
# Threshold 0.2855, F1: 0.7868
# Threshold 0.2862, F1: 0.7866
# Threshold 0.2869, F1: 0.7865
# Threshold 0.2875, F1: 0.7879
# Threshold 0.2882, F1: 0.7879
# Threshold 0.2889, F1: 0.7881
# Threshold 0.2895, F1: 0.7881
# Threshold 0.2902, F1: 0.7883
# Threshold 0.2909, F1: 0.7884
# Threshold 0.2915, F1: 0.7885
# Threshold 0.2922, F1: 0.7882
# Threshold 0.2929, F1: 0.7883
# Threshold 0.2935, F1: 0.7884
# Threshold 0.2942, F1: 0.7888
# Threshold 0.2949, F1: 0.7888
# Threshold 0.2955, F1: 0.7886
# Threshold 0.2962, F1: 0.7890
# Threshold 0.2969, F1: 0.7893
# Threshold 0.2975, F1: 0.7894
# Threshold 0.2982, F1: 0.7892
# Threshold 0.2989, F1: 0.7894
# Threshold 0.2995, F1: 0.7895
# Threshold 0.3002, F1: 0.7891
# Threshold 0.3009, F1: 0.7890
# Threshold 0.3015, F1: 0.7891
# Threshold 0.3022, F1: 0.7892
# Threshold 0.3029, F1: 0.7893
# Threshold 0.3035, F1: 0.7895
# Threshold 0.3042, F1: 0.7895
# Threshold 0.3049, F1: 0.7897
# Threshold 0.3055, F1: 0.7896
# Threshold 0.3062, F1: 0.7896
# Threshold 0.3069, F1: 0.7895
# Threshold 0.3075, F1: 0.7894
# Threshold 0.3082, F1: 0.7894
# Threshold 0.3089, F1: 0.7896
# Threshold 0.3095, F1: 0.7890
# Threshold 0.3102, F1: 0.7890
# Threshold 0.3109, F1: 0.7911
# Threshold 0.3115, F1: 0.7911
# Threshold 0.3122, F1: 0.7916
# Threshold 0.3129, F1: 0.7916
# Threshold 0.3135, F1: 0.7912
# Threshold 0.3142, F1: 0.7913
# Threshold 0.3149, F1: 0.7891
# Threshold 0.3155, F1: 0.7894
# Threshold 0.3162, F1: 0.7894
# Threshold 0.3169, F1: 0.7892
# Threshold 0.3175, F1: 0.7891
# Threshold 0.3182, F1: 0.7889
# Threshold 0.3189, F1: 0.7889
# Threshold 0.3195, F1: 0.7891
# Threshold 0.3202, F1: 0.7870
# Threshold 0.3209, F1: 0.7867
# Threshold 0.3215, F1: 0.7866
# Threshold 0.3222, F1: 0.7864
# Threshold 0.3229, F1: 0.7864
# Threshold 0.3235, F1: 0.7869
# Threshold 0.3242, F1: 0.7872
# Threshold 0.3249, F1: 0.7877
# Threshold 0.3256, F1: 0.7873
# Threshold 0.3262, F1: 0.7871
# Threshold 0.3269, F1: 0.7864
# Threshold 0.3276, F1: 0.7865
# Threshold 0.3282, F1: 0.7864
# Threshold 0.3289, F1: 0.7862
# Threshold 0.3296, F1: 0.7860
# Threshold 0.3302, F1: 0.7859
# Threshold 0.3309, F1: 0.7855
# Threshold 0.3316, F1: 0.7844
# Threshold 0.3322, F1: 0.7848
# Threshold 0.3329, F1: 0.7848
# Threshold 0.3336, F1: 0.7847
# Threshold 0.3342, F1: 0.7850
# Threshold 0.3349, F1: 0.7850
# Threshold 0.3356, F1: 0.7850
# Threshold 0.3362, F1: 0.7847
# Threshold 0.3369, F1: 0.7845
# Threshold 0.3376, F1: 0.7847
# Threshold 0.3382, F1: 0.7847
# Threshold 0.3389, F1: 0.7848
# Threshold 0.3396, F1: 0.7844
# Threshold 0.3402, F1: 0.7844
# Threshold 0.3409, F1: 0.7844
# Threshold 0.3416, F1: 0.7843
# Threshold 0.3422, F1: 0.7842
# Threshold 0.3429, F1: 0.7844
# Threshold 0.3436, F1: 0.7845
# Threshold 0.3442, F1: 0.7844
# Threshold 0.3449, F1: 0.7843
# Threshold 0.3456, F1: 0.7843
# Threshold 0.3462, F1: 0.7843
# Threshold 0.3469, F1: 0.7841
# Threshold 0.3476, F1: 0.7841
# Threshold 0.3482, F1: 0.7841
# Threshold 0.3489, F1: 0.7839
# Threshold 0.3496, F1: 0.7840
# Threshold 0.3502, F1: 0.7839
# Threshold 0.3509, F1: 0.7839
# Threshold 0.3516, F1: 0.7839
# Threshold 0.3522, F1: 0.7839
# Threshold 0.3529, F1: 0.7835
# Threshold 0.3536, F1: 0.7834
# Threshold 0.3542, F1: 0.7834
# Threshold 0.3549, F1: 0.7808
# Threshold 0.3556, F1: 0.7808
# Threshold 0.3562, F1: 0.7808
# Threshold 0.3569, F1: 0.7808
# Threshold 0.3576, F1: 0.7806
# Threshold 0.3582, F1: 0.7805
# Threshold 0.3589, F1: 0.7803
# Threshold 0.3596, F1: 0.7803
# Threshold 0.3602, F1: 0.7742
# Threshold 0.3609, F1: 0.7741
# Threshold 0.3616, F1: 0.7737
# Threshold 0.3622, F1: 0.7739
# Threshold 0.3629, F1: 0.7740
# Threshold 0.3636, F1: 0.7735
# Threshold 0.3642, F1: 0.7735
# Threshold 0.3649, F1: 0.7713
# Threshold 0.3656, F1: 0.7713
# Threshold 0.3662, F1: 0.7711
# Threshold 0.3669, F1: 0.7711
# Threshold 0.3676, F1: 0.7710
# Threshold 0.3682, F1: 0.7712
# Threshold 0.3689, F1: 0.7717
# Threshold 0.3696, F1: 0.7716
# Threshold 0.3702, F1: 0.7717
# Threshold 0.3709, F1: 0.7718
# Threshold 0.3716, F1: 0.7719
# Threshold 0.3722, F1: 0.7716
# Threshold 0.3729, F1: 0.7710
# Threshold 0.3736, F1: 0.7704
# Threshold 0.3742, F1: 0.7700
# Threshold 0.3749, F1: 0.7700
# Threshold 0.3756, F1: 0.7698
# Threshold 0.3763, F1: 0.7695
# Threshold 0.3769, F1: 0.7691
# Threshold 0.3776, F1: 0.7687
# Threshold 0.3783, F1: 0.7687
# Threshold 0.3789, F1: 0.7691
# Threshold 0.3796, F1: 0.7698
# Threshold 0.3803, F1: 0.7698
# Threshold 0.3809, F1: 0.7699
# Threshold 0.3816, F1: 0.7699
# Threshold 0.3823, F1: 0.7697
# Threshold 0.3829, F1: 0.7697
# Threshold 0.3836, F1: 0.7700
# Threshold 0.3843, F1: 0.7701
# Threshold 0.3849, F1: 0.7703
# Threshold 0.3856, F1: 0.7701
# Threshold 0.3863, F1: 0.7702
# Threshold 0.3869, F1: 0.7698
# Threshold 0.3876, F1: 0.7698
# Threshold 0.3883, F1: 0.7696
# Threshold 0.3889, F1: 0.7693
# Threshold 0.3896, F1: 0.7691
# Threshold 0.3903, F1: 0.7691
# Threshold 0.3909, F1: 0.7692
# Threshold 0.3916, F1: 0.7690
# Threshold 0.3923, F1: 0.7686
# Threshold 0.3929, F1: 0.7686
# Threshold 0.3936, F1: 0.7686
# Threshold 0.3943, F1: 0.7682
# Threshold 0.3949, F1: 0.7684
# Threshold 0.3956, F1: 0.7677
# Threshold 0.3963, F1: 0.7674
# Threshold 0.3969, F1: 0.7678
# Threshold 0.3976, F1: 0.7677
# Threshold 0.3983, F1: 0.7675
# Threshold 0.3989, F1: 0.7674
# Threshold 0.3996, F1: 0.7677
# Threshold 0.4003, F1: 0.7682
# Threshold 0.4009, F1: 0.7681
# Threshold 0.4016, F1: 0.7678
# Threshold 0.4023, F1: 0.7677
# Threshold 0.4029, F1: 0.7676
# Threshold 0.4036, F1: 0.7680
# Threshold 0.4043, F1: 0.7683
# Threshold 0.4049, F1: 0.7677
# Threshold 0.4056, F1: 0.7665
# Threshold 0.4063, F1: 0.7662
# Threshold 0.4069, F1: 0.7657
# Threshold 0.4076, F1: 0.7656
# Threshold 0.4083, F1: 0.7656
# Threshold 0.4089, F1: 0.7627
# Threshold 0.4096, F1: 0.7622
# Threshold 0.4103, F1: 0.7621
# Threshold 0.4109, F1: 0.7624
# Threshold 0.4116, F1: 0.7624
# Threshold 0.4123, F1: 0.7621
# Threshold 0.4129, F1: 0.7621
# Threshold 0.4136, F1: 0.7619
# Threshold 0.4143, F1: 0.7616
# Threshold 0.4149, F1: 0.7614
# Threshold 0.4156, F1: 0.7609
# Threshold 0.4163, F1: 0.7608
# Threshold 0.4169, F1: 0.7608
# Threshold 0.4176, F1: 0.7607
# Threshold 0.4183, F1: 0.7606
# Threshold 0.4189, F1: 0.7604
# Threshold 0.4196, F1: 0.7604
# Threshold 0.4203, F1: 0.7597
# Threshold 0.4209, F1: 0.7599
# Threshold 0.4216, F1: 0.7597
# Threshold 0.4223, F1: 0.7596
# Threshold 0.4229, F1: 0.7596
# Threshold 0.4236, F1: 0.7598
# Threshold 0.4243, F1: 0.7597
# Threshold 0.4249, F1: 0.7595
# Threshold 0.4256, F1: 0.7595
# Threshold 0.4263, F1: 0.7595
# Threshold 0.4270, F1: 0.7595
# Threshold 0.4276, F1: 0.7592
# Threshold 0.4283, F1: 0.7592
# Threshold 0.4290, F1: 0.7585
# Threshold 0.4296, F1: 0.7584
# Threshold 0.4303, F1: 0.7579
# Threshold 0.4310, F1: 0.7579
# Threshold 0.4316, F1: 0.7570
# Threshold 0.4323, F1: 0.7570
# Threshold 0.4330, F1: 0.7569
# Threshold 0.4336, F1: 0.7561
# Threshold 0.4343, F1: 0.7556
# Threshold 0.4350, F1: 0.7317
# Threshold 0.4356, F1: 0.7318
# Threshold 0.4363, F1: 0.7320
# Threshold 0.4370, F1: 0.7317
# Threshold 0.4376, F1: 0.7317
# Threshold 0.4383, F1: 0.7317
# Threshold 0.4390, F1: 0.7315
# Threshold 0.4396, F1: 0.7314
# Threshold 0.4403, F1: 0.7312
# Threshold 0.4410, F1: 0.7313
# Threshold 0.4416, F1: 0.7306
# Threshold 0.4423, F1: 0.7306
# Threshold 0.4430, F1: 0.7301
# Threshold 0.4436, F1: 0.7300
# Threshold 0.4443, F1: 0.7300
# Threshold 0.4450, F1: 0.7300
# Threshold 0.4456, F1: 0.7295
# /home/haider/anaconda3/envs/fastai-v1/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Threshold 0.4463, F1: 0.7294
# Threshold 0.4470, F1: 0.7291
# Threshold 0.4476, F1: 0.7285
# Threshold 0.4483, F1: 0.7282
# Threshold 0.4490, F1: 0.7282
# Threshold 0.4496, F1: 0.7280
# Threshold 0.4503, F1: 0.7295
# Threshold 0.4510, F1: 0.7294
# Threshold 0.4516, F1: 0.7291
# Threshold 0.4523, F1: 0.7290
# Threshold 0.4530, F1: 0.7290
# Threshold 0.4536, F1: 0.7290
# Threshold 0.4543, F1: 0.7290
# Threshold 0.4550, F1: 0.7289
# Threshold 0.4556, F1: 0.7290
# Threshold 0.4563, F1: 0.7283
# Threshold 0.4570, F1: 0.7276
# Threshold 0.4576, F1: 0.7277
# Threshold 0.4583, F1: 0.7277
# Threshold 0.4590, F1: 0.7274
# Threshold 0.4596, F1: 0.7274
# Threshold 0.4603, F1: 0.7272
# Threshold 0.4610, F1: 0.7271
# Threshold 0.4616, F1: 0.7272
# Threshold 0.4623, F1: 0.7270
# Threshold 0.4630, F1: 0.7262
# Threshold 0.4636, F1: 0.7262
# Threshold 0.4643, F1: 0.7260
# Threshold 0.4650, F1: 0.7259
# Threshold 0.4656, F1: 0.7258
# Threshold 0.4663, F1: 0.7255
# Threshold 0.4670, F1: 0.7257
# Threshold 0.4676, F1: 0.7256
# Threshold 0.4683, F1: 0.7254
# Threshold 0.4690, F1: 0.7255
# Threshold 0.4696, F1: 0.7253
# Threshold 0.4703, F1: 0.7254
# Threshold 0.4710, F1: 0.7253
# Threshold 0.4716, F1: 0.7254
# Threshold 0.4723, F1: 0.7254
# Threshold 0.4730, F1: 0.7251
# Threshold 0.4736, F1: 0.7251
# Threshold 0.4743, F1: 0.7254
# Threshold 0.4750, F1: 0.7245
# Threshold 0.4757, F1: 0.7242
# Threshold 0.4763, F1: 0.7241
# Threshold 0.4770, F1: 0.7242
# Threshold 0.4777, F1: 0.7245
# Threshold 0.4783, F1: 0.7244
# Threshold 0.4790, F1: 0.7244
# Threshold 0.4797, F1: 0.7234
# Threshold 0.4803, F1: 0.7234
# Threshold 0.4810, F1: 0.7235
# Threshold 0.4817, F1: 0.7226
# Threshold 0.4823, F1: 0.7225
# Threshold 0.4830, F1: 0.7223
# Threshold 0.4837, F1: 0.7223
# Threshold 0.4843, F1: 0.7221
# Threshold 0.4850, F1: 0.7222
# Threshold 0.4857, F1: 0.7222
# Threshold 0.4863, F1: 0.7220
# Threshold 0.4870, F1: 0.7218
# Threshold 0.4877, F1: 0.7215
# Threshold 0.4883, F1: 0.7209
# Threshold 0.4890, F1: 0.7207
# Threshold 0.4897, F1: 0.7209
# Threshold 0.4903, F1: 0.7207
# Threshold 0.4910, F1: 0.7173
# Threshold 0.4917, F1: 0.7165
# Threshold 0.4923, F1: 0.7165
# Threshold 0.4930, F1: 0.7165
# Threshold 0.4937, F1: 0.7154
# Threshold 0.4943, F1: 0.7155
# Threshold 0.4950, F1: 0.7154
# Threshold 0.4957, F1: 0.7154
# Threshold 0.4963, F1: 0.7152
# Threshold 0.4970, F1: 0.7152
# Threshold 0.4977, F1: 0.7151
# Threshold 0.4983, F1: 0.7148
# Threshold 0.4990, F1: 0.7149
# Threshold 0.4997, F1: 0.7143
# Threshold 0.5003, F1: 0.7138
# Threshold 0.5010, F1: 0.7135
# Threshold 0.5017, F1: 0.7136
# Threshold 0.5023, F1: 0.7125
# Threshold 0.5030, F1: 0.7123
# Threshold 0.5037, F1: 0.7074
# Threshold 0.5043, F1: 0.7016
# Threshold 0.5050, F1: 0.7015
# Threshold 0.5057, F1: 0.7005
# Threshold 0.5063, F1: 0.7004
# Threshold 0.5070, F1: 0.7003
# Threshold 0.5077, F1: 0.6999
# Threshold 0.5083, F1: 0.7000
# Threshold 0.5090, F1: 0.6999
# Threshold 0.5097, F1: 0.6999
# Threshold 0.5103, F1: 0.6992
# Threshold 0.5110, F1: 0.6992
# Threshold 0.5117, F1: 0.6993
# Threshold 0.5123, F1: 0.6989
# Threshold 0.5130, F1: 0.6988
# Threshold 0.5137, F1: 0.6988
# Threshold 0.5143, F1: 0.6985
# Threshold 0.5150, F1: 0.6983
# Threshold 0.5157, F1: 0.6983
# Threshold 0.5163, F1: 0.6978
# Threshold 0.5170, F1: 0.6978
# Threshold 0.5177, F1: 0.6978
# Threshold 0.5183, F1: 0.6982
# Threshold 0.5190, F1: 0.6981
# Threshold 0.5197, F1: 0.6981
# Threshold 0.5203, F1: 0.6976
# Threshold 0.5210, F1: 0.6966
# Threshold 0.5217, F1: 0.6962
# Threshold 0.5223, F1: 0.6961
# Threshold 0.5230, F1: 0.6961
# Threshold 0.5237, F1: 0.6953
# Threshold 0.5243, F1: 0.6951
# Threshold 0.5250, F1: 0.6950
# Threshold 0.5257, F1: 0.6946
# Threshold 0.5264, F1: 0.6944
# Threshold 0.5270, F1: 0.6940
# Threshold 0.5277, F1: 0.6937
# Threshold 0.5284, F1: 0.6929
# Threshold 0.5290, F1: 0.6924
# Threshold 0.5297, F1: 0.6916
# Threshold 0.5304, F1: 0.6917
# Threshold 0.5310, F1: 0.6911
# Threshold 0.5317, F1: 0.6908
# Threshold 0.5324, F1: 0.6896
# Threshold 0.5330, F1: 0.6893
# Threshold 0.5337, F1: 0.6889
# Threshold 0.5344, F1: 0.6889
# Threshold 0.5350, F1: 0.6887
# Threshold 0.5357, F1: 0.6887
# Threshold 0.5364, F1: 0.6885
# Threshold 0.5370, F1: 0.6884
# Threshold 0.5377, F1: 0.6881
# Threshold 0.5384, F1: 0.6885
# Threshold 0.5390, F1: 0.6877
# Threshold 0.5397, F1: 0.6876
# Threshold 0.5404, F1: 0.6872
# Threshold 0.5410, F1: 0.6871
# Threshold 0.5417, F1: 0.6868
# Threshold 0.5424, F1: 0.6872
# Threshold 0.5430, F1: 0.6873
# Threshold 0.5437, F1: 0.6871
# Threshold 0.5444, F1: 0.6867
# Threshold 0.5450, F1: 0.6869
# Threshold 0.5457, F1: 0.6868
# Threshold 0.5464, F1: 0.6866
# Threshold 0.5470, F1: 0.6866
# Threshold 0.5477, F1: 0.6865
# Threshold 0.5484, F1: 0.6863
# Threshold 0.5490, F1: 0.6865
# Threshold 0.5497, F1: 0.6864
# Threshold 0.5504, F1: 0.6864
# Threshold 0.5510, F1: 0.6863
# Threshold 0.5517, F1: 0.6861
# Threshold 0.5524, F1: 0.6860
# Threshold 0.5530, F1: 0.6857
# Threshold 0.5537, F1: 0.6858
# Threshold 0.5544, F1: 0.6856
# Threshold 0.5550, F1: 0.6855
# Threshold 0.5557, F1: 0.6852
# Threshold 0.5564, F1: 0.6849
# Threshold 0.5570, F1: 0.6848
# Threshold 0.5577, F1: 0.6848
# Threshold 0.5584, F1: 0.6848
# Threshold 0.5590, F1: 0.6816
# Threshold 0.5597, F1: 0.6816
# Threshold 0.5604, F1: 0.6815
# Threshold 0.5610, F1: 0.6814
# Threshold 0.5617, F1: 0.6817
# Threshold 0.5624, F1: 0.6815
# Threshold 0.5630, F1: 0.6812
# Threshold 0.5637, F1: 0.6809
# Threshold 0.5644, F1: 0.6808
# Threshold 0.5650, F1: 0.6808
# Threshold 0.5657, F1: 0.6804
# Threshold 0.5664, F1: 0.6805
# Threshold 0.5670, F1: 0.6802
# Threshold 0.5677, F1: 0.6802
# Threshold 0.5684, F1: 0.6805
# Threshold 0.5690, F1: 0.6803
# Threshold 0.5697, F1: 0.6795
# Threshold 0.5704, F1: 0.6794
# Threshold 0.5710, F1: 0.6796
# Threshold 0.5717, F1: 0.6794
# Threshold 0.5724, F1: 0.6786
# Threshold 0.5730, F1: 0.6785
# Threshold 0.5737, F1: 0.6759
# Threshold 0.5744, F1: 0.6758
# Threshold 0.5751, F1: 0.6753
# Threshold 0.5757, F1: 0.6673
# Threshold 0.5764, F1: 0.6672
# Threshold 0.5771, F1: 0.6670
# Threshold 0.5777, F1: 0.6671
# Threshold 0.5784, F1: 0.6667
# Threshold 0.5791, F1: 0.6664
# Threshold 0.5797, F1: 0.6653
# Threshold 0.5804, F1: 0.6650
# Threshold 0.5811, F1: 0.6647
# Threshold 0.5817, F1: 0.6645
# Threshold 0.5824, F1: 0.6644
# Threshold 0.5831, F1: 0.6641
# Threshold 0.5837, F1: 0.6638
# Threshold 0.5844, F1: 0.6638
# Threshold 0.5851, F1: 0.6637
# Threshold 0.5857, F1: 0.6636
# Threshold 0.5864, F1: 0.6634
# Threshold 0.5871, F1: 0.6633
# Threshold 0.5877, F1: 0.6632
# Threshold 0.5884, F1: 0.6632
# Threshold 0.5891, F1: 0.6632
# Threshold 0.5897, F1: 0.6627
# Threshold 0.5904, F1: 0.6623
# Threshold 0.5911, F1: 0.6622
# Threshold 0.5917, F1: 0.6620
# Threshold 0.5924, F1: 0.6619
# Threshold 0.5931, F1: 0.6617
# Threshold 0.5937, F1: 0.6615
# Threshold 0.5944, F1: 0.6615
# Threshold 0.5951, F1: 0.6613
# Threshold 0.5957, F1: 0.6614
# Threshold 0.5964, F1: 0.6571
# Threshold 0.5971, F1: 0.6576
# Threshold 0.5977, F1: 0.6575
# Threshold 0.5984, F1: 0.6559
# Threshold 0.5991, F1: 0.6558
# Threshold 0.5997, F1: 0.6556
# Threshold 0.6004, F1: 0.6556
# Threshold 0.6011, F1: 0.6555
# Threshold 0.6017, F1: 0.6554
# Threshold 0.6024, F1: 0.6551
# Threshold 0.6031, F1: 0.6548
# Threshold 0.6037, F1: 0.6547
# Threshold 0.6044, F1: 0.6546
# Threshold 0.6051, F1: 0.6544
# Threshold 0.6057, F1: 0.6542
# Threshold 0.6064, F1: 0.6541
# Threshold 0.6071, F1: 0.6544
# Threshold 0.6077, F1: 0.6543
# Threshold 0.6084, F1: 0.6541
# Threshold 0.6091, F1: 0.6493
# Threshold 0.6097, F1: 0.6491
# Threshold 0.6104, F1: 0.6481
# Threshold 0.6111, F1: 0.6479
# Threshold 0.6117, F1: 0.6479
# Threshold 0.6124, F1: 0.6476
# Threshold 0.6131, F1: 0.6471
# Threshold 0.6137, F1: 0.6471
# Threshold 0.6144, F1: 0.6467
# Threshold 0.6151, F1: 0.6464
# Threshold 0.6157, F1: 0.6459
# Threshold 0.6164, F1: 0.6458
# Threshold 0.6171, F1: 0.6444
# Threshold 0.6177, F1: 0.6441
# Threshold 0.6184, F1: 0.6440
# Threshold 0.6191, F1: 0.6440
# Threshold 0.6197, F1: 0.6436
# Threshold 0.6204, F1: 0.6434
# Threshold 0.6211, F1: 0.6430
# Threshold 0.6217, F1: 0.6421
# Threshold 0.6224, F1: 0.6407
# Threshold 0.6231, F1: 0.6408
# Threshold 0.6237, F1: 0.6406
# Threshold 0.6244, F1: 0.6404
# Threshold 0.6251, F1: 0.6404
# Threshold 0.6258, F1: 0.6402
# Threshold 0.6264, F1: 0.6398
# Threshold 0.6271, F1: 0.6394
# Threshold 0.6278, F1: 0.6394
# Threshold 0.6284, F1: 0.6392
# Threshold 0.6291, F1: 0.6391
# Threshold 0.6298, F1: 0.6390
# Threshold 0.6304, F1: 0.6383
# Threshold 0.6311, F1: 0.6374
# Threshold 0.6318, F1: 0.6365
# Threshold 0.6324, F1: 0.6363
# Threshold 0.6331, F1: 0.6363
# Threshold 0.6338, F1: 0.6362
# Threshold 0.6344, F1: 0.6361
# Threshold 0.6351, F1: 0.6360
# Threshold 0.6358, F1: 0.6358
# Threshold 0.6364, F1: 0.6358
# Threshold 0.6371, F1: 0.6356
# Threshold 0.6378, F1: 0.6355
# Threshold 0.6384, F1: 0.6353
# Threshold 0.6391, F1: 0.6353
# Threshold 0.6398, F1: 0.6350
# Threshold 0.6404, F1: 0.6344
# Threshold 0.6411, F1: 0.6342
# Threshold 0.6418, F1: 0.6341
# Threshold 0.6424, F1: 0.6339
# Threshold 0.6431, F1: 0.6337
# Threshold 0.6438, F1: 0.6335
# Threshold 0.6444, F1: 0.6334
# Threshold 0.6451, F1: 0.6331
# Threshold 0.6458, F1: 0.6331
# Threshold 0.6464, F1: 0.6331
# Threshold 0.6471, F1: 0.6328
# Threshold 0.6478, F1: 0.6328
# Threshold 0.6484, F1: 0.6326
# Threshold 0.6491, F1: 0.6322
# Threshold 0.6498, F1: 0.6320
# Threshold 0.6504, F1: 0.6310
# Threshold 0.6511, F1: 0.6304
# Threshold 0.6518, F1: 0.6304
# Threshold 0.6524, F1: 0.6302
# Threshold 0.6531, F1: 0.6300
# Threshold 0.6538, F1: 0.6301
# Threshold 0.6544, F1: 0.6297
# Threshold 0.6551, F1: 0.6290
# Threshold 0.6558, F1: 0.6285
# Threshold 0.6564, F1: 0.6285
# Threshold 0.6571, F1: 0.6284
# Threshold 0.6578, F1: 0.6276
# Threshold 0.6584, F1: 0.6272
# Threshold 0.6591, F1: 0.6268
# Threshold 0.6598, F1: 0.6192
# Threshold 0.6604, F1: 0.6189
# Threshold 0.6611, F1: 0.6188
# Threshold 0.6618, F1: 0.6183
# Threshold 0.6624, F1: 0.6182
# Threshold 0.6631, F1: 0.6179
# Threshold 0.6638, F1: 0.6178
# Threshold 0.6644, F1: 0.6167
# Threshold 0.6651, F1: 0.6163
# Threshold 0.6658, F1: 0.6156
# Threshold 0.6664, F1: 0.6145
# Threshold 0.6671, F1: 0.6144
# Threshold 0.6678, F1: 0.6145
# Threshold 0.6684, F1: 0.6138
# Threshold 0.6691, F1: 0.6134
# Threshold 0.6698, F1: 0.6133
# Threshold 0.6704, F1: 0.6130
# Threshold 0.6711, F1: 0.6127
# Threshold 0.6718, F1: 0.6126
# Threshold 0.6724, F1: 0.6126
# Threshold 0.6731, F1: 0.6112
# Threshold 0.6738, F1: 0.6112
# Threshold 0.6744, F1: 0.6110
# Threshold 0.6751, F1: 0.6061
# Threshold 0.6758, F1: 0.6054
# Threshold 0.6765, F1: 0.6049
# Threshold 0.6771, F1: 0.6048
# Threshold 0.6778, F1: 0.6045
# Threshold 0.6785, F1: 0.6033
# Threshold 0.6791, F1: 0.6030
# Threshold 0.6798, F1: 0.6028
# Threshold 0.6805, F1: 0.6028
# Threshold 0.6811, F1: 0.6025
# Threshold 0.6818, F1: 0.6022
# Threshold 0.6825, F1: 0.6013
# Threshold 0.6831, F1: 0.6012
# Threshold 0.6838, F1: 0.6010
# Threshold 0.6845, F1: 0.6013
# Threshold 0.6851, F1: 0.6011
# Threshold 0.6858, F1: 0.6008
# Threshold 0.6865, F1: 0.6007
# Threshold 0.6871, F1: 0.6003
# Threshold 0.6878, F1: 0.6001
# Threshold 0.6885, F1: 0.6001
# Threshold 0.6891, F1: 0.5996
# Threshold 0.6898, F1: 0.5995
# Threshold 0.6905, F1: 0.5993
# Threshold 0.6911, F1: 0.5989
# Threshold 0.6918, F1: 0.5989
# Threshold 0.6925, F1: 0.5988
# Threshold 0.6931, F1: 0.5987
# Threshold 0.6938, F1: 0.5984
# Threshold 0.6945, F1: 0.5982
# Threshold 0.6951, F1: 0.5980
# Threshold 0.6958, F1: 0.5975
# Threshold 0.6965, F1: 0.5971
# Threshold 0.6971, F1: 0.5969
# Threshold 0.6978, F1: 0.5966
# Threshold 0.6985, F1: 0.5948
# Threshold 0.6991, F1: 0.5948
# Threshold 0.6998, F1: 0.5948
# Threshold 0.7005, F1: 0.5945
# Threshold 0.7011, F1: 0.5944
# Threshold 0.7018, F1: 0.5940
# Threshold 0.7025, F1: 0.5917
# Threshold 0.7031, F1: 0.5912
# Threshold 0.7038, F1: 0.5909
# Threshold 0.7045, F1: 0.5909
# Threshold 0.7051, F1: 0.5906
# Threshold 0.7058, F1: 0.5905
# Threshold 0.7065, F1: 0.5902
# Threshold 0.7071, F1: 0.5892
# Threshold 0.7078, F1: 0.5890
# Threshold 0.7085, F1: 0.5886
# Threshold 0.7091, F1: 0.5886
# Threshold 0.7098, F1: 0.5883
# Threshold 0.7105, F1: 0.5865
# Threshold 0.7111, F1: 0.5862
# Threshold 0.7118, F1: 0.5861
# Threshold 0.7125, F1: 0.5858
# Threshold 0.7131, F1: 0.5857
# Threshold 0.7138, F1: 0.5850
# Threshold 0.7145, F1: 0.5850
# Threshold 0.7151, F1: 0.5836
# Threshold 0.7158, F1: 0.5835
# Threshold 0.7165, F1: 0.5833
# Threshold 0.7171, F1: 0.5830
# Threshold 0.7178, F1: 0.5825
# Threshold 0.7185, F1: 0.5825
# Threshold 0.7191, F1: 0.5824
# Threshold 0.7198, F1: 0.5823
# Threshold 0.7205, F1: 0.5822
# Threshold 0.7211, F1: 0.5795
# Threshold 0.7218, F1: 0.5794
# Threshold 0.7225, F1: 0.5788
# Threshold 0.7231, F1: 0.5784
# Threshold 0.7238, F1: 0.5782
# Threshold 0.7245, F1: 0.5773
# Threshold 0.7252, F1: 0.5762
# Threshold 0.7258, F1: 0.5759
# Threshold 0.7265, F1: 0.5757
# Threshold 0.7272, F1: 0.5755
# Threshold 0.7278, F1: 0.5754
# Threshold 0.7285, F1: 0.5742
# Threshold 0.7292, F1: 0.5725
# Threshold 0.7298, F1: 0.5720
# Threshold 0.7305, F1: 0.5717
# Threshold 0.7312, F1: 0.5683
# Threshold 0.7318, F1: 0.5680
# Threshold 0.7325, F1: 0.5676
# Threshold 0.7332, F1: 0.5672
# Threshold 0.7338, F1: 0.5668
# Threshold 0.7345, F1: 0.5667
# Threshold 0.7352, F1: 0.5660
# Threshold 0.7358, F1: 0.5658
# Threshold 0.7365, F1: 0.5618
# Threshold 0.7372, F1: 0.5617
# Threshold 0.7378, F1: 0.5613
# Threshold 0.7385, F1: 0.5608
# Threshold 0.7392, F1: 0.5599
# Threshold 0.7398, F1: 0.5597
# Threshold 0.7405, F1: 0.5493
# Threshold 0.7412, F1: 0.5492
# Threshold 0.7418, F1: 0.5487
# Threshold 0.7425, F1: 0.5483
# Threshold 0.7432, F1: 0.5479
# Threshold 0.7438, F1: 0.5479
# Threshold 0.7445, F1: 0.5418
# Threshold 0.7452, F1: 0.5417
# Threshold 0.7458, F1: 0.5414
# Threshold 0.7465, F1: 0.5413
# Threshold 0.7472, F1: 0.5396
# Threshold 0.7478, F1: 0.5392
# Threshold 0.7485, F1: 0.5391
# Threshold 0.7492, F1: 0.5383
# Threshold 0.7498, F1: 0.5370
# Threshold 0.7505, F1: 0.5363
# Threshold 0.7512, F1: 0.5355
# Threshold 0.7518, F1: 0.5329
# Threshold 0.7525, F1: 0.5321
# Threshold 0.7532, F1: 0.5320
# Threshold 0.7538, F1: 0.5316
# Threshold 0.7545, F1: 0.5315
# Threshold 0.7552, F1: 0.5296
# Threshold 0.7558, F1: 0.5296
# Threshold 0.7565, F1: 0.5294
# Threshold 0.7572, F1: 0.5286
# Threshold 0.7578, F1: 0.5285
# Threshold 0.7585, F1: 0.5278
# Threshold 0.7592, F1: 0.5272
# Threshold 0.7598, F1: 0.5269
# Threshold 0.7605, F1: 0.5261
# Threshold 0.7612, F1: 0.5259
# Threshold 0.7618, F1: 0.5250
# Threshold 0.7625, F1: 0.5247
# Threshold 0.7632, F1: 0.5244
# Threshold 0.7638, F1: 0.5238
# Threshold 0.7645, F1: 0.5236
# Threshold 0.7652, F1: 0.5234
# Threshold 0.7658, F1: 0.5230
# Threshold 0.7665, F1: 0.5229
# Threshold 0.7672, F1: 0.5223
# Threshold 0.7678, F1: 0.5203
# Threshold 0.7685, F1: 0.5203
# Threshold 0.7692, F1: 0.5199
# Threshold 0.7698, F1: 0.5197
# Threshold 0.7705, F1: 0.5194
# Threshold 0.7712, F1: 0.5192
# Threshold 0.7718, F1: 0.5183
# Threshold 0.7725, F1: 0.5175
# Threshold 0.7732, F1: 0.5156
# Threshold 0.7738, F1: 0.5148
# Threshold 0.7745, F1: 0.5143
# Threshold 0.7752, F1: 0.5139
# Threshold 0.7759, F1: 0.5134
# Threshold 0.7765, F1: 0.5128
# Threshold 0.7772, F1: 0.5122
# Threshold 0.7779, F1: 0.5118
# Threshold 0.7785, F1: 0.5115
# Threshold 0.7792, F1: 0.5112
# Threshold 0.7799, F1: 0.5101
# Threshold 0.7805, F1: 0.5099
# Threshold 0.7812, F1: 0.5093
# Threshold 0.7819, F1: 0.5092
# Threshold 0.7825, F1: 0.5082
# Threshold 0.7832, F1: 0.5069
# Threshold 0.7839, F1: 0.5067
# Threshold 0.7845, F1: 0.5062
# Threshold 0.7852, F1: 0.5046
# Threshold 0.7859, F1: 0.5032
# Threshold 0.7865, F1: 0.5025
# Threshold 0.7872, F1: 0.5020
# Threshold 0.7879, F1: 0.5014
# Threshold 0.7885, F1: 0.5008
# Threshold 0.7892, F1: 0.5005
# Threshold 0.7899, F1: 0.4999
# Threshold 0.7905, F1: 0.4999
# Threshold 0.7912, F1: 0.4995
# Threshold 0.7919, F1: 0.4986
# Threshold 0.7925, F1: 0.4984
# Threshold 0.7932, F1: 0.4974
# Threshold 0.7939, F1: 0.4957
# Threshold 0.7945, F1: 0.4948
# Threshold 0.7952, F1: 0.4948
# Threshold 0.7959, F1: 0.4946
# Threshold 0.7965, F1: 0.4943
# Threshold 0.7972, F1: 0.4941
# Threshold 0.7979, F1: 0.4936
# Threshold 0.7985, F1: 0.4922
# Threshold 0.7992, F1: 0.4921
# Threshold 0.7999, F1: 0.4915
# Threshold 0.8005, F1: 0.4914
# Threshold 0.8012, F1: 0.4909
# Threshold 0.8019, F1: 0.4902
# Threshold 0.8025, F1: 0.4896
# Threshold 0.8032, F1: 0.4893
# Threshold 0.8039, F1: 0.4889
# Threshold 0.8045, F1: 0.4885
# Threshold 0.8052, F1: 0.4885
# Threshold 0.8059, F1: 0.4865
# Threshold 0.8065, F1: 0.4863
# Threshold 0.8072, F1: 0.4860
# Threshold 0.8079, F1: 0.4850
# Threshold 0.8085, F1: 0.4838
# Threshold 0.8092, F1: 0.4832
# Threshold 0.8099, F1: 0.4826
# Threshold 0.8105, F1: 0.4822
# Threshold 0.8112, F1: 0.4822
# Threshold 0.8119, F1: 0.4820
# Threshold 0.8125, F1: 0.4818
# Threshold 0.8132, F1: 0.4812
# Threshold 0.8139, F1: 0.4803
# Threshold 0.8145, F1: 0.4795
# Threshold 0.8152, F1: 0.4793
# Threshold 0.8159, F1: 0.4792
# Threshold 0.8165, F1: 0.4787
# Threshold 0.8172, F1: 0.4786
# Threshold 0.8179, F1: 0.4781
# Threshold 0.8185, F1: 0.4737
# Threshold 0.8192, F1: 0.4725
# Threshold 0.8199, F1: 0.4723
# Threshold 0.8205, F1: 0.4652
# Threshold 0.8212, F1: 0.4647
# Threshold 0.8219, F1: 0.4642
# Threshold 0.8225, F1: 0.4640
# Threshold 0.8232, F1: 0.4638
# Threshold 0.8239, F1: 0.4637
# Threshold 0.8245, F1: 0.4636
# Threshold 0.8252, F1: 0.4628
# Threshold 0.8259, F1: 0.4618
# Threshold 0.8266, F1: 0.4610
# Threshold 0.8272, F1: 0.4610
# Threshold 0.8279, F1: 0.4608
# Threshold 0.8286, F1: 0.4599
# Threshold 0.8292, F1: 0.4591
# Threshold 0.8299, F1: 0.4590
# Threshold 0.8306, F1: 0.4574
# Threshold 0.8312, F1: 0.4564
# Threshold 0.8319, F1: 0.4561
# Threshold 0.8326, F1: 0.4554
# Threshold 0.8332, F1: 0.4552
# Threshold 0.8339, F1: 0.4547
# Threshold 0.8346, F1: 0.4543
# Threshold 0.8352, F1: 0.4539
# Threshold 0.8359, F1: 0.4536
# Threshold 0.8366, F1: 0.4532
# Threshold 0.8372, F1: 0.4528
# Threshold 0.8379, F1: 0.4515
# Threshold 0.8386, F1: 0.4507
# Threshold 0.8392, F1: 0.4491
# Threshold 0.8399, F1: 0.4490
# Threshold 0.8406, F1: 0.4487
# Threshold 0.8412, F1: 0.4480
# Threshold 0.8419, F1: 0.4476
# Threshold 0.8426, F1: 0.4471
# Threshold 0.8432, F1: 0.4467
# Threshold 0.8439, F1: 0.4459
# Threshold 0.8446, F1: 0.4451
# Threshold 0.8452, F1: 0.4450
# Threshold 0.8459, F1: 0.4444
# Threshold 0.8466, F1: 0.4438
# Threshold 0.8472, F1: 0.4437
# Threshold 0.8479, F1: 0.4430
# Threshold 0.8486, F1: 0.4339
# Threshold 0.8492, F1: 0.4335
# Threshold 0.8499, F1: 0.4307
# Threshold 0.8506, F1: 0.4302
# Threshold 0.8512, F1: 0.4284
# Threshold 0.8519, F1: 0.4283
# Threshold 0.8526, F1: 0.4281
# Threshold 0.8532, F1: 0.4270
# Threshold 0.8539, F1: 0.4256
# Threshold 0.8546, F1: 0.4248
# Threshold 0.8552, F1: 0.4244
# Threshold 0.8559, F1: 0.4235
# Threshold 0.8566, F1: 0.4207
# Threshold 0.8572, F1: 0.4203
# Threshold 0.8579, F1: 0.4194
# Threshold 0.8586, F1: 0.4189
# Threshold 0.8592, F1: 0.4185
# Threshold 0.8599, F1: 0.4180
# Threshold 0.8606, F1: 0.4167
# Threshold 0.8612, F1: 0.4160
# Threshold 0.8619, F1: 0.4156
# Threshold 0.8626, F1: 0.4153
# Threshold 0.8632, F1: 0.4150
# Threshold 0.8639, F1: 0.4146
# Threshold 0.8646, F1: 0.4139
# Threshold 0.8652, F1: 0.4135
# Threshold 0.8659, F1: 0.4125
# Threshold 0.8666, F1: 0.4115
# Threshold 0.8672, F1: 0.4113
# Threshold 0.8679, F1: 0.4107
# Threshold 0.8686, F1: 0.4104
# Threshold 0.8692, F1: 0.4099
# Threshold 0.8699, F1: 0.4089
# Threshold 0.8706, F1: 0.4074
# Threshold 0.8712, F1: 0.4057
# Threshold 0.8719, F1: 0.4044
# Threshold 0.8726, F1: 0.4039
# Threshold 0.8732, F1: 0.4037
# Threshold 0.8739, F1: 0.4030
# Threshold 0.8746, F1: 0.4025
# Threshold 0.8753, F1: 0.4017
# Threshold 0.8759, F1: 0.4006
# Threshold 0.8766, F1: 0.3998
# Threshold 0.8773, F1: 0.3990
# Threshold 0.8779, F1: 0.3983
# Threshold 0.8786, F1: 0.3981
# Threshold 0.8793, F1: 0.3975
# Threshold 0.8799, F1: 0.3965
# Threshold 0.8806, F1: 0.3954
# Threshold 0.8813, F1: 0.3948
# Threshold 0.8819, F1: 0.3939
# Threshold 0.8826, F1: 0.3931
# Threshold 0.8833, F1: 0.3925
# Threshold 0.8839, F1: 0.3922
# Threshold 0.8846, F1: 0.3917
# Threshold 0.8853, F1: 0.3864
# Threshold 0.8859, F1: 0.3856
# Threshold 0.8866, F1: 0.3851
# Threshold 0.8873, F1: 0.3841
# Threshold 0.8879, F1: 0.3837
# Threshold 0.8886, F1: 0.3835
# Threshold 0.8893, F1: 0.3826
# Threshold 0.8899, F1: 0.3815
# Threshold 0.8906, F1: 0.3809
# Threshold 0.8913, F1: 0.3802
# Threshold 0.8919, F1: 0.3797
# Threshold 0.8926, F1: 0.3793
# Threshold 0.8933, F1: 0.3792
# Threshold 0.8939, F1: 0.3789
# Threshold 0.8946, F1: 0.3773
# Threshold 0.8953, F1: 0.3756
# Threshold 0.8959, F1: 0.3752
# Threshold 0.8966, F1: 0.3748
# Threshold 0.8973, F1: 0.3744
# Threshold 0.8979, F1: 0.3738
# Threshold 0.8986, F1: 0.3733
# Threshold 0.8993, F1: 0.3711
# Threshold 0.8999, F1: 0.3691
# Threshold 0.9006, F1: 0.3686
# Threshold 0.9013, F1: 0.3680
# Threshold 0.9019, F1: 0.3677
# Threshold 0.9026, F1: 0.3665
# Threshold 0.9033, F1: 0.3661
# Threshold 0.9039, F1: 0.3644
# Threshold 0.9046, F1: 0.3636
# Threshold 0.9053, F1: 0.3616
# Threshold 0.9059, F1: 0.3607
# Threshold 0.9066, F1: 0.3599
# Threshold 0.9073, F1: 0.3591
# Threshold 0.9079, F1: 0.3584
# Threshold 0.9086, F1: 0.3568
# Threshold 0.9093, F1: 0.3564
# Threshold 0.9099, F1: 0.3547
# Threshold 0.9106, F1: 0.3530
# Threshold 0.9113, F1: 0.3525
# Threshold 0.9119, F1: 0.3505
# Threshold 0.9126, F1: 0.3501
# Threshold 0.9133, F1: 0.3488
# Threshold 0.9139, F1: 0.3477
# Threshold 0.9146, F1: 0.3471
# Threshold 0.9153, F1: 0.3457
# Threshold 0.9159, F1: 0.3435
# Threshold 0.9166, F1: 0.3430
# Threshold 0.9173, F1: 0.3424
# Threshold 0.9179, F1: 0.3365
# Threshold 0.9186, F1: 0.3355
# Threshold 0.9193, F1: 0.3341
# Threshold 0.9199, F1: 0.3339
# Threshold 0.9206, F1: 0.3320
# Threshold 0.9213, F1: 0.3313
# Threshold 0.9219, F1: 0.3305
# Threshold 0.9226, F1: 0.3290
# Threshold 0.9233, F1: 0.3274
# Threshold 0.9239, F1: 0.3255
# Threshold 0.9246, F1: 0.3249
# Threshold 0.9253, F1: 0.3240
# Threshold 0.9260, F1: 0.3219
# Threshold 0.9266, F1: 0.3204
# Threshold 0.9273, F1: 0.3193
# Threshold 0.9280, F1: 0.3184
# Threshold 0.9286, F1: 0.3169
# Threshold 0.9293, F1: 0.3156
# Threshold 0.9300, F1: 0.3145
# Threshold 0.9306, F1: 0.3127
# Threshold 0.9313, F1: 0.3111
# Threshold 0.9320, F1: 0.3100
# Threshold 0.9326, F1: 0.3092
# Threshold 0.9333, F1: 0.3077
# Threshold 0.9340, F1: 0.3072
# Threshold 0.9346, F1: 0.3059
# Threshold 0.9353, F1: 0.3031
# Threshold 0.9360, F1: 0.2962
# Threshold 0.9366, F1: 0.2956
# Threshold 0.9373, F1: 0.2944
# Threshold 0.9380, F1: 0.2923
# Threshold 0.9386, F1: 0.2913
# Threshold 0.9393, F1: 0.2894
# Threshold 0.9400, F1: 0.2878
# Threshold 0.9406, F1: 0.2864
# Threshold 0.9413, F1: 0.2853
# Threshold 0.9420, F1: 0.2839
# Threshold 0.9426, F1: 0.2816
# Threshold 0.9433, F1: 0.2810
# Threshold 0.9440, F1: 0.2791
# Threshold 0.9446, F1: 0.2781
# Threshold 0.9453, F1: 0.2768
# Threshold 0.9460, F1: 0.2746
# Threshold 0.9466, F1: 0.2729
# Threshold 0.9473, F1: 0.2719
# Threshold 0.9480, F1: 0.2699
# Threshold 0.9486, F1: 0.2684
# Threshold 0.9493, F1: 0.2674
# Threshold 0.9500, F1: 0.2663
# Threshold 0.9506, F1: 0.2644
# Threshold 0.9513, F1: 0.2627
# Threshold 0.9520, F1: 0.2611
# Threshold 0.9526, F1: 0.2603
# Threshold 0.9533, F1: 0.2582
# Threshold 0.9540, F1: 0.2570
# Threshold 0.9546, F1: 0.2554
# Threshold 0.9553, F1: 0.2538
# Threshold 0.9560, F1: 0.2526
# Threshold 0.9566, F1: 0.2491
# Threshold 0.9573, F1: 0.2474
# Threshold 0.9580, F1: 0.2461
# Threshold 0.9586, F1: 0.2450
# Threshold 0.9593, F1: 0.2435
# Threshold 0.9600, F1: 0.2410
# Threshold 0.9606, F1: 0.2394
# Threshold 0.9613, F1: 0.2366
# Threshold 0.9620, F1: 0.2345
# Threshold 0.9626, F1: 0.2329
# Threshold 0.9633, F1: 0.2315
# Threshold 0.9640, F1: 0.2287
# Threshold 0.9646, F1: 0.2264
# Threshold 0.9653, F1: 0.2244
# Threshold 0.9660, F1: 0.2215
# Threshold 0.9666, F1: 0.2194
# Threshold 0.9673, F1: 0.2165
# Threshold 0.9680, F1: 0.2138
# Threshold 0.9686, F1: 0.2116
# Threshold 0.9693, F1: 0.2089
# Threshold 0.9700, F1: 0.1982
# Threshold 0.9706, F1: 0.1963
# Threshold 0.9713, F1: 0.1938
# Threshold 0.9720, F1: 0.1907
# Threshold 0.9726, F1: 0.1884
# Threshold 0.9733, F1: 0.1849
# Threshold 0.9740, F1: 0.1814
# Threshold 0.9746, F1: 0.1767
# Threshold 0.9753, F1: 0.1738
# Threshold 0.9760, F1: 0.1710
# Threshold 0.9767, F1: 0.1670
# Threshold 0.9773, F1: 0.1643
# Threshold 0.9780, F1: 0.1595
# Threshold 0.9787, F1: 0.1567
# Threshold 0.9793, F1: 0.1530
# Threshold 0.9800, F1: 0.1490
# Threshold 0.9807, F1: 0.1454
# Threshold 0.9813, F1: 0.1416
# Threshold 0.9820, F1: 0.1375
# Threshold 0.9827, F1: 0.1316
# Threshold 0.9833, F1: 0.1266
# Threshold 0.9840, F1: 0.1225
# Threshold 0.9847, F1: 0.1160
# Threshold 0.9853, F1: 0.1101
# Threshold 0.9860, F1: 0.1076
# Threshold 0.9867, F1: 0.1036
# Threshold 0.9873, F1: 0.0999
# Threshold 0.9880, F1: 0.0960
# Threshold 0.9887, F1: 0.0910
# Threshold 0.9893, F1: 0.0854
# Threshold 0.9900, F1: 0.0802
# Threshold 0.9907, F1: 0.0738
# Threshold 0.9913, F1: 0.0691
# Threshold 0.9920, F1: 0.0617
# Threshold 0.9927, F1: 0.0545
# Threshold 0.9933, F1: 0.0483
# Threshold 0.9940, F1: 0.0432
# Threshold 0.9947, F1: 0.0367
# Threshold 0.9953, F1: 0.0315
# Threshold 0.9960, F1: 0.0259
# Threshold 0.9967, F1: 0.0196
# Threshold 0.9973, F1: 0.0154
# Threshold 0.9980, F1: 0.0098
# Threshold 0.9987, F1: 0.0035
# Threshold 0.9993, F1: 0.0004
# Threshold 1.0000, F1: 0.0000
# BEST: 0.24283, F1: 0.79226

# %%
preds_np= to_np(preds)

thresholds = np.linspace(0, 1, 100)
score = 0.0
test_threshold=0.5*np.ones(28)
best_threshold=np.zeros(28)
best_val = np.zeros(28)
for i in range(28):
    for threshold in thresholds:
        test_threshold[i] = threshold
        # max_val = np.max(preds)
        # import pdb; pdb.set_trace()
        val_predict = (preds_np > test_threshold)
        score = f1_score(y > 0.5, val_predict, average='macro')
        if score > best_val[i]:
            best_threshold[i] = threshold
            best_val[i] = score

    print("Threshold[%d] %0.6f, F1: %0.6f" % (i,best_threshold[i],best_val[i]))
    test_threshold[i] = best_threshold[i]
print("Best threshold: ")
print(best_threshold)
print("Best f1:")
print(best_val)
# Out:
# Threshold[0] 0.404040, F1: 0.714238
# Threshold[1] 0.242424, F1: 0.715214
# Threshold[2] 0.313131, F1: 0.716193
# Threshold[3] 0.363636, F1: 0.716742
# Threshold[4] 0.252525, F1: 0.717982
# Threshold[5] 0.303030, F1: 0.719480
# Threshold[6] 0.333333, F1: 0.721254
# Threshold[7] 0.333333, F1: 0.722005
# Threshold[8] 0.090909, F1: 0.732209
# Threshold[9] 0.121212, F1: 0.741608
# Threshold[10] 0.313131, F1: 0.744355
# Threshold[11] 0.262626, F1: 0.744684
# Threshold[12] 0.303030, F1: 0.745787
# Threshold[13] 0.222222, F1: 0.747507
# Threshold[14] 0.484848, F1: 0.747788
# Threshold[15] 0.141414, F1: 0.754931
# Threshold[16] 0.282828, F1: 0.758583
# Threshold[17] 0.424242, F1: 0.762863
# Threshold[18] 0.282828, F1: 0.764512
# Threshold[19] 0.303030, F1: 0.766572
# Threshold[20] 0.242424, F1: 0.771582
# Threshold[21] 0.212121, F1: 0.773855
# Threshold[22] 0.292929, F1: 0.776705
# Threshold[23] 0.303030, F1: 0.777599
# Threshold[24] 0.646465, F1: 0.778439
# Threshold[25] 0.363636, F1: 0.779286
# Threshold[26] 0.272727, F1: 0.785029
# Threshold[27] 0.030303, F1: 0.820743
# Best threshold:
# [0.40404  0.242424 0.313131 0.363636 0.252525 0.30303  0.333333 0.333333 0.090909 0.121212 0.313131 0.262626 0.30303
#  0.222222 0.484848 0.141414 0.282828 0.424242 0.282828 0.30303  0.242424 0.212121 0.292929 0.30303  0.646465 0.363636
#  0.272727 0.030303]
# Best f1:
# [0.714238 0.715214 0.716193 0.716742 0.717982 0.71948  0.721254 0.722005 0.732209 0.741608 0.744355 0.744684 0.745787
#  0.747507 0.747788 0.754931 0.758583 0.762863 0.764512 0.766572 0.771582 0.773855 0.776705 0.777599 0.778439 0.779286
#  0.785029 0.820743]

# %%
best_threshold
# Out:
# array([0.40404 , 0.242424, 0.313131, 0.363636, 0.252525, 0.30303 , 0.333333, 0.333333, 0.090909, 0.121212, 0.313131,
#        0.262626, 0.30303 , 0.222222, 0.484848, 0.141414, 0.282828, 0.424242, 0.282828, 0.30303 , 0.242424, 0.212121,
#        0.292929, 0.30303 , 0.646465, 0.363636, 0.272727, 0.030303])

# %% [markdown]
# **Submission**

# %%
name = 'ensemble_4_mdls_after_training_extrads_in_2_days'

preds_t,_ = learn.get_preds(DatasetType.Test)
pred_labels = [' '.join(list([str(i) for i in np.nonzero(row>best_threshold)[0]])) for row in np.array(preds_t)]
df = pd.DataFrame({'Id':test_ids,'Predicted':pred_labels})
df.to_csv(path/'subs'/f'{name}.csv', header=True, index=False)

# %%
# !kaggle competitions submit -c human-protein-atlas-image-classification -f {path}/subs/{name}.csv -m "'ensemble_4_mdls_in_rush'"
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/haider/.kaggle/kaggle.json'
# 100%|████████████████████████████████████████| 469k/469k [00:13<00:00, 35.6kB/s]
# Successfully submitted to Human Protein Atlas Image Classification
